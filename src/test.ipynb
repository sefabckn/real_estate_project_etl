# %%
from bs4 import BeautifulSoup
import requests

# %%
BASE_URL = "https://books.toscrape.com/catalogue/page-{}.html"

# %%
def fetch_html(url):
    """
    Fetches HTML content from a URL with basic error handling
   
    """
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status() # Error messages if there is an erro while reaching the url
        return response.text
    except requests.RequestException as e: 
        print(f"Error while Fetching: {url}: {e}")
        return None

# %%
fetch_html(BASE_URL)
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" hr
# ...

# %%
soup = BeautifulSoup(fetch_html(BASE_URL), 'html.parser')

for article in soup.find_all('article', class_='product_pod'):
    image_url =  "https://books.toscrape.com/" + article.find('a').find('img')['src']
    
    title = article.find('h3').find('a')['title']
    price = article.find('p', class_='price_color').text
    star_reviews = article.find('p', class_='star-rating')['class']
    rating = [x for x in star_reviews if x != 'star-rating'][0]
    in_stock = article.find('p', class_='availability')
# Out:
# Error while Fetching: https://books.toscrape.com/catalogue/page-{1}.html: 404 Client Error: Not Found for url: https://books.toscrape.com/catalogue/page-%7B1%7D.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 soup = BeautifulSoup(fetch_html(BASE_URL), 'html.parser')
#       3 for article in soup.find_all('article', class_='product_pod'):
#       4     image_url =  "https://books.toscrape.com/" + article.find('a').find('img')['src']
#
# File c:\Users\afesb\Desktop\Real estate project\venv\Lib\site-packages\bs4\__init__.py:445, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     443     markup = cast(io.IOBase, markup).read()
#     444 elif not isinstance(markup, (bytes, str)) and not hasattr(markup, "__len__"):
# --> 445     raise TypeError(
# ...

# %%
import datetime

# %%
def parse_books(html_content):

    soup = BeautifulSoup(html_content, 'html.parser')
    books = []

    for article in soup.find_all('article', class_='product_pod'):
        try:
            image_url =  "https://books.toscrape.com/" + article.find('a').find('img')['src']
            title = article.find('h3').find('a')['title']
            price = article.find('p', class_='price_color').text
            star_reviews = article.find('p', class_='star-rating')['class']
            rating = [x for x in star_reviews if x != 'star-rating'][0]
            in_stock = article.find('p', class_='availability')

            books.append({
                'img':image_url,
                'title': title,
                'price': price,
                'rating': rating,
                'availability': in_stock,
                'scrapped_at' : datetime.now().isoformat()
            })
        except AttributeError:
            continue #skip if any element is missing
    return books

parse_books(fetch_html(BASE_URL))
# Out:
# Error while Fetching: https://books.toscrape.com/catalogue/page-{1}.html: 404 Client Error: Not Found for url: https://books.toscrape.com/catalogue/page-%7B1%7D.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 27
#      24             continue #skip if any element is missing
#      25     return books
# ---> 27 parse_books(fetch_html(BASE_URL))
#
# Cell In[37], line 3, in parse_books(html_content)
#       1 def parse_books(html_content):
# ----> 3     soup = BeautifulSoup(html_content, 'html.parser')
#       4     books = []
#       6     for article in soup.find_all('article', class_='product_pod'):
#
# File c:\Users\afesb\Desktop\Real estate project\venv\Lib\site-packages\bs4\__init__.py:445, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
# ...

# %%
soup = BeautifulSoup(fetch_html(BASE_URL), 'html.parser')
books = []

for article in soup.find_all('article', class_='product_pod'):
    try:
        image_url =  "https://books.toscrape.com/" + article.find('a').find('img')['src']
        print(image_url)
        title = article.find('h3').find('a')['title']
        price = article.find('p', class_='price_color').text
        star_reviews = article.find('p', class_='star-rating')['class']
        rating = [x for x in star_reviews if x != 'star-rating'][0]
        in_stock = article.find('p', class_='availability')

        books.append({
            'img': image_url,
            'title': title,
            'price': price,
            'rating': rating,
            'availability': in_stock,
            'scrapped_at': datetime.now().isoformat()
        })
    except AttributeError:
        continue  # skip if any element is missing
# Out:
# Error while Fetching: https://books.toscrape.com/catalogue/page-{}.html: 404 Client Error: Not Found for url: https://books.toscrape.com/catalogue/page-%7B%7D.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 soup = BeautifulSoup(fetch_html(BASE_URL), 'html.parser')
#       2 books = []
#       4 for article in soup.find_all('article', class_='product_pod'):
#
# File c:\Users\afesb\Desktop\Real estate project\venv\Lib\site-packages\bs4\__init__.py:445, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     443     markup = cast(io.IOBase, markup).read()
#     444 elif not isinstance(markup, (bytes, str)) and not hasattr(markup, "__len__"):
# --> 445     raise TypeError(
# ...

# %%
import time

# %%
pages_to_scrape =5
for page in range(1, pages_to_scrape + 1):
    url = BASE_URL.format(page)
    print(url)
# Out:
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-2.html
# https://books.toscrape.com/catalogue/page-3.html
# https://books.toscrape.com/catalogue/page-4.html
# https://books.toscrape.com/catalogue/page-5.html

# %%
BASE_URL = "https://books.toscrape.com/catalogue/page-{}.html"

def fetch_html(url):
    """
    Fetches HTML content from a URL with basic error handling
   
    """
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status() # Error messages if there is an erro while reaching the url
        return response.text
    except requests.RequestException as e: 
        print(f"Error while Fetching: {url}: {e}")
        return None
    

def parse_books(html_content):

    soup = BeautifulSoup(html_content, 'html.parser')
    books = []

    for article in soup.find_all('article', class_='product_pod'):
        try:
            image_url =  "https://books.toscrape.com/" + article.find('a').find('img')['src']
            title = article.find('h3').find('a')['title']
            price = article.find('p', class_='price_color').text
            star_reviews = article.find('p', class_='star-rating')['class']
            rating = [x for x in star_reviews if x != 'star-rating'][0]
            in_stock = article.find('p', class_='availability')
            
            books.append({
                'img':image_url,
                'title': title,
                'price': price,
                'rating': rating,
                'availability': in_stock,
                'scrapped_at' : datetime.now().isoformat()
            })
            
        except AttributeError:
            continue #skip if any element is missing
    return books

def run_scraper(pages_to_scrape =5):
    """
    Main function to orchestrate the scrapping
    """
    print(f"🚀 Starting scraper for {pages_to_scrape} pages...")

    all_data = []
    for page in range(1, pages_to_scrape+1):
        url = BASE_URL.format(page)

        html = fetch_html(url)

        if html:
            data = parse_books(html)
            all_data.extend(data)

        time.sleep(1)

    print(f'Scrapping complete. Collected {len(all_data)} items.')
    return(all_data)


if __name__ == '__main__':
    data = run_scraper(pages_to_scrape=3)
    print(data[:2])
# Out:
# 🚀 Starting scraper for 3 pages...
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# append starts after here
# ...

# %%
BASE_URL = 'https://books.toscrape.com'
def fetch_html(url):
    """
    Fetches HTML content from a URL with basic error handling
   
    """
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status() # Error messages if there is an erro while reaching the url
        return response.text
    except requests.RequestException as e: 
        print(f"Error while Fetching: {url}: {e}")
        return None

# %%
from urllib.parse import urljoin
soup = BeautifulSoup(fetch_html(BASE_URL), 'html.parser')
books = []

for article in soup.find_all('article', class_='product_pod'):
        
    img_tag = article.find('img')
    image_url = urljoin("https://books.toscrape.com/catalogue/", img_tag['src'])
    title = article.find('h3').find('a')['title']
    price = article.find('p', class_='price_color').text
    star_reviews = article.find('p', class_='star-rating')['class']
    rating = [x for x in star_reviews if x != 'star-rating'][0]
    in_stock = article.find('p', class_='instock availability')
    availability_text = in_stock.text.strip() if in_stock else 'N/A'
    print(image_url)
# Out:
# https://books.toscrape.com/catalogue/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg
# https://books.toscrape.com/catalogue/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg
# https://books.toscrape.com/catalogue/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg
# https://books.toscrape.com/catalogue/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg
# https://books.toscrape.com/catalogue/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg
# https://books.toscrape.com/catalogue/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg
# https://books.toscrape.com/catalogue/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg
# https://books.toscrape.com/catalogue/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg
# https://books.toscrape.com/catalogue/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg
# https://books.toscrape.com/catalogue/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg
# ...

# %%
import datetime

# %%
datetime.now().isoformat()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 datetime.now().isoformat()
#
# AttributeError: module 'datetime' has no attribute 'now'

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime
import time
from urllib.parse import urljoin

BASE_URL = "https://books.toscrape.com/catalogue/page-{}.html"

def fetch_html(url):
    """
    Fetches HTML content from a URL with basic error handling
   
    """
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status() # Error messages if there is an erro while reaching the url
        return response.text
    except requests.RequestException as e: 
        print(f"Error while Fetching: {url}: {e}")
        return None
    

def parse_books(html_content):

    soup = BeautifulSoup(html_content, 'html.parser')
    books = []

    for article in soup.find_all('article', class_='product_pod'):
        try:
            img_tag = article.find('img')
            image_url = urljoin("https://books.toscrape.com/catalogue/", img_tag['src'])
            
            title = article.find('h3').find('a')['title']
            price = article.find('p', class_='price_color').text
            star_reviews = article.find('p', class_='star-rating')['class']
            rating = [x for x in star_reviews if x != 'star-rating'][0]
            
            in_stock = article.find('p', class_='instock availability')
            availability_text = in_stock.text.strip() if in_stock else 'N/A'

            books.append({
                'img': image_url,
                'title': title,
                'price': price,
                'rating': rating,
                'availability': availability_text,
                'scrapped_at': datetime.now().isoformat()
            })
        except AttributeError as e:
            print(f"⚠️ Skipping book due to missing element: {e}")
            continue
    return books

def run_scraper(pages_to_scrape =5):
    """
    Main function to orchestrate the scraping
    """
    print(f"🚀 Starting scraper for {pages_to_scrape} pages...")

    all_data = []
    
    for page in range(1, pages_to_scrape+1):
    
        # ... URL logic (using the fixed logic for page 1) ...
        if page == 1:
            url = "https://books.toscrape.com/"
        else:
            url = BASE_URL.format(page)
        # ...
    
        html = fetch_html(url)
        
        # --- DEBUGGING PRINTS ADDED HERE ---
        if html:
            # Print the length of the HTML received
            print(f"✅ Success! Received {len(html)} bytes of HTML from {url}") 
            
            data = parse_books(html)
            
            # Print how many items were found by the parser
            print(f"📦 Parser found {len(data)} items on this page.") 

            all_data.extend(data)
        else:
            # This means fetch_html failed and printed an error
            print(f"❌ Failed to retrieve content for page {page}. Moving to next.")
        
    time.sleep(1)

    print(f'Scrapping complete. Collected {len(all_data)} items.')
    return all_data


if __name__ == '__main__':
    # You should now collect 20 books per page, so 60 items for 3 pages.
    data = run_scraper(pages_to_scrape=3)
    print(data[:2])
# Out:
# 🚀 Starting scraper for 3 pages...
# ✅ Success! Received 51294 bytes of HTML from https://books.toscrape.com/
# 📦 Parser found 20 items on this page.
# ✅ Success! Received 50877 bytes of HTML from https://books.toscrape.com/catalogue/page-2.html
# 📦 Parser found 20 items on this page.
# ✅ Success! Received 51374 bytes of HTML from https://books.toscrape.com/catalogue/page-3.html
# 📦 Parser found 20 items on this page.
# Scrapping complete. Collected 60 items.
# [{'img': 'https://books.toscrape.com/catalogue/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg', 'title': 'A Light in the Attic', 'price': 'Â£51.77', 'rating': 'Three', 'availability': 'In stock', 'scrapped_at': '2025-12-02T22:06:25.282749'}, {'img': 'https://books.toscrape.com/catalogue/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg', 'title': 'Tipping the Velvet', 'price': 'Â£53.74', 'rating': 'One', 'availability': 'In stock', 'scrapped_at': '2025-12-02T22:06:25.282865'}]

# %%
data[:1]
# Out:
# [{'img': 'https://books.toscrape.com/catalogue/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg',
#   'title': 'A Light in the Attic',
#   'price': 'Â£51.77',
#   'rating': 'Three',
#   'availability': 'In stock',
#   'scrapped_at': '2025-12-02T22:06:25.282749'}]

# %%
for i in data[:1]:
    for j in i.items():
        print(j)
# Out:
# ('img', 'https://books.toscrape.com/catalogue/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg')
# ('title', 'A Light in the Attic')
# ('price', 'Â£51.77')
# ('rating', 'Three')
# ('availability', 'In stock')
# ('scrapped_at', '2025-12-02T22:06:25.282749')

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head(3)
# Out:
#                                                  img                 title  \
# 0  https://books.toscrape.com/catalogue/media/cac...  A Light in the Attic
# 1  https://books.toscrape.com/catalogue/media/cac...    Tipping the Velvet
# 2  https://books.toscrape.com/catalogue/media/cac...            Soumission
#
#      price rating availability                 scrapped_at
# 0  Â£51.77  Three     In stock  2025-12-02T22:06:25.282749
# 1  Â£53.74    One     In stock  2025-12-02T22:06:25.282865
# 2  Â£50.10    One     In stock  2025-12-02T22:06:25.283036

# %%
df['price'] = df['price'].astype(str).str.extract(r'(\d+\.\d+)').astype(float)

# %%
df['price']
# Out:
# 0     51.77
# 1     53.74
# 2     50.10
# 3     47.82
# 4     54.23
# 5     22.65
# 6     33.34
# 7     17.93
# 8     22.60
# 9     52.15
# 10    13.99
# 11    20.66
# 12    17.46
# 13    52.29
# 14    35.02
# 15    57.25
# 16    23.88
# 17    37.59
# 18    51.33
# 19    45.17
# 20    12.84
# 21    37.32
# 22    30.52
# 23    25.27
# 24    34.53
# 25    54.64
# 26    22.50
# 27    53.13
# 28    40.30
# 29    44.18
# 30    17.66
# 31    31.05
# 32    23.82
# 33    36.89
# 34    15.94
# 35    33.29
# 36    18.02
# 37    19.63
# 38    52.22
# 39    33.63
# 40    57.31
# 41    26.41
# 42    47.61
# 43    23.11
# 44    45.07
# 45    31.77
# 46    50.27
# 47    14.27
# 48    44.18
# 49    18.78
# 50    25.52
# 51    16.28
# 52    31.12
# 53    19.49
# 54    17.27
# 55    19.09
# 56    56.13
# 57    56.41
# 58    56.50
# 59    45.22
# Name: price, dtype: float64

# %%
RATING_MAP = {
    'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 
    'Zero': 0, 'N/A': 0
}

# %%
df['rating'] = df['rating'].map(RATING_MAP).fillna(0).astype(int)

# %%
df['rating'].tail()
# Out:
# 55      One
# 56      One
# 57      One
# 58     Four
# 59    Three
# Name: rating, dtype: object

# %%
a = df['rating'].map(RATING_MAP).fillna(0).astype(int)

# %%
a
# Out:
# 0     3
# 1     1
# 2     1
# 3     4
# 4     5
# 5     1
# 6     4
# 7     3
# 8     4
# 9     1
# 10    2
# 11    4
# 12    5
# 13    5
# 14    5
# 15    3
# 16    1
# 17    1
# 18    2
# 19    2
# 20    1
# 21    2
# 22    3
# 23    5
# 24    5
# 25    3
# 26    3
# 27    3
# 28    5
# 29    4
# 30    5
# 31    3
# 32    5
# 33    1
# 34    5
# 35    3
# 36    2
# 37    1
# 38    4
# 39    2
# 40    3
# 41    2
# 42    5
# 43    5
# 44    2
# 45    1
# 46    5
# 47    4
# 48    4
# 49    3
# 50    1
# 51    1
# 52    3
# 53    4
# 54    5
# 55    1
# 56    1
# 57    1
# 58    4
# 59    3
# Name: rating, dtype: int64

# %%
df['rating'].head()
# Out:
# 0    3
# 1    1
# 2    1
# 3    4
# 4    5
# Name: rating, dtype: int64

# %%
df['rating'].map(RATING_MAP).fillna(0).astype(int)
# Out:
# 0     3
# 1     1
# 2     1
# 3     4
# 4     5
# 5     1
# 6     4
# 7     3
# 8     4
# 9     1
# 10    2
# 11    4
# 12    5
# 13    5
# 14    5
# 15    3
# 16    1
# 17    1
# 18    2
# 19    2
# 20    1
# 21    2
# 22    3
# 23    5
# 24    5
# 25    3
# 26    3
# 27    3
# 28    5
# 29    4
# 30    5
# 31    3
# 32    5
# 33    1
# 34    5
# 35    3
# 36    2
# 37    1
# 38    4
# 39    2
# 40    3
# 41    2
# 42    5
# 43    5
# 44    2
# 45    1
# 46    5
# 47    4
# 48    4
# 49    3
# 50    1
# 51    1
# 52    3
# 53    4
# 54    5
# 55    1
# 56    1
# 57    1
# 58    4
# 59    3
# Name: rating, dtype: int64

# %%
df_cleaned = df.rename(columns={'scrapped_at': 'scrapped_timestamps'})

# %%
# Out:
# Index(['img', 'title', 'price', 'rating', 'availability',
#        'scrapped_timestamps'],
#       dtype='object')

# %%
def clean_data(data: list) -> pd.DataFrame:
    df = pd.DataFrame(data)

    if(df.empty):
        print('⚠️ DataFrame is empty, No Data to clean')
        return df
    
    """
    Sample output of data 
        ('img', 'https://books.toscrape.com/catalogue/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg')
        ('title', 'A Light in the Attic')
        ('price', 'Â£51.77')
        ('rating', 'Three')
        ('availability', 'In stock')
        ('scrapped_at', '2025-12-02T22:06:25.282749')
    """
    df['price'] = df['price'].astype(str).str.extract(r'(\d+\.\d+)').astype(float)

    df['rating'] = df['rating'].map(RATING_MAP).fillna(0).astype(int)

    df['scrapped_at'] = pd.to_datetime(df['scrapped_at'])

    df_cleaned = df.rename(columns = {'scrapped_at': 'scraped_timestamp'})

    final_cols = ['img', 'title', 'price', 'rating', 'availability',
       'scraped_timestamp']
    
    return df_cleaned[final_cols]

# %%
clean_data(data).head()
# Out:
#                                                  img  \
# 0  https://books.toscrape.com/catalogue/media/cac...
# 1  https://books.toscrape.com/catalogue/media/cac...
# 2  https://books.toscrape.com/catalogue/media/cac...
# 3  https://books.toscrape.com/catalogue/media/cac...
# 4  https://books.toscrape.com/catalogue/media/cac...
#
#                                    title  price  rating availability  \
# 0                   A Light in the Attic  51.77       3     In stock
# 1                     Tipping the Velvet  53.74       1     In stock
# 2                             Soumission  50.10       1     In stock
# 3                          Sharp Objects  47.82       4     In stock
# 4  Sapiens: A Brief History of Humankind  54.23       5     In stock
#
#            scraped_timestamp
# 0 2025-12-02 22:06:25.282749
# 1 2025-12-02 22:06:25.282865
# 2 2025-12-02 22:06:25.283036
# 3 2025-12-02 22:06:25.283139
# 4 2025-12-02 22:06:25.283236

# %%
df.head()
# Out:
#                                                  img  \
# 0  https://books.toscrape.com/catalogue/media/cac...
# 1  https://books.toscrape.com/catalogue/media/cac...
# 2  https://books.toscrape.com/catalogue/media/cac...
# 3  https://books.toscrape.com/catalogue/media/cac...
# 4  https://books.toscrape.com/catalogue/media/cac...
#
#                                    title    price rating availability  \
# 0                   A Light in the Attic  Â£51.77  Three     In stock
# 1                     Tipping the Velvet  Â£53.74    One     In stock
# 2                             Soumission  Â£50.10    One     In stock
# 3                          Sharp Objects  Â£47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five     In stock
#
#                   scrapped_at
# 0  2025-12-02T22:06:25.282749
# 1  2025-12-02T22:06:25.282865
# 2  2025-12-02T22:06:25.283036
# 3  2025-12-02T22:06:25.283139
# 4  2025-12-02T22:06:25.283236

# %%
df['scrapped_at'] = pd.to_datetime(df['scrapped_at'])

# %%
df.head()
# Out:
#                                                  img  \
# 0  https://books.toscrape.com/catalogue/media/cac...
# 1  https://books.toscrape.com/catalogue/media/cac...
# 2  https://books.toscrape.com/catalogue/media/cac...
# 3  https://books.toscrape.com/catalogue/media/cac...
# 4  https://books.toscrape.com/catalogue/media/cac...
#
#                                    title    price rating availability  \
# 0                   A Light in the Attic  Â£51.77  Three     In stock
# 1                     Tipping the Velvet  Â£53.74    One     In stock
# 2                             Soumission  Â£50.10    One     In stock
# 3                          Sharp Objects  Â£47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five     In stock
#
#                  scrapped_at
# 0 2025-12-02 22:06:25.282749
# 1 2025-12-02 22:06:25.282865
# 2 2025-12-02 22:06:25.283036
# 3 2025-12-02 22:06:25.283139
# 4 2025-12-02 22:06:25.283236

# %%
import os

os.path.dirname(os.path.dirname(__file__), 'data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 import os
# ----> 3 os.path.dirname(os.path.dirname(__file__), 'data')
#
# NameError: name '__file__' is not defined

# %%
DB_PATH = os.path.join(os.path.dirname(os.path.dirname(__file__)), 'data', 'books_data.db')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 DB_PATH = os.path.join(os.path.dirname(os.path.dirname(__file__)), 'data', 'books_data.db')
#
# NameError: name '__file__' is not defined

# %%
os.path
# Out:
# <module 'ntpath' (frozen)>

# %%
df_cleaned.columns
# Out:
# Index(['img', 'title', 'price', 'rating', 'availability',
#        'scrapped_timestamps'],
#       dtype='object')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\afesb\\Desktop\\Real estate project\\src'

# %%
os.chdir("c:/Users/afesb/Desktop/Real estate project")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\afesb\\Desktop\\Real estate project'

# %%
os.listdir('.') # lists the content of a folder
# Out:
# ['.env', '.git', '.gitignore', 'app.py', 'data', 'README.md', 'src', 'venv']

# %%
os.mkdir('new_folder_test')

# %%
os.chdir(path='new_folder_test')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\afesb\\Desktop\\Real estate project\\new_folder_test'

# %%
os.listdir('.')
# Out:
# []

# %%
os.makedirs("parent/child/grandchild", exist_ok=True)

# %%
os.listdir('.')
# Out:
# ['parent']

# %%
os.chdir(path='parent')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\afesb\\Desktop\\Real estate project\\new_folder_test\\parent'

# %%
os.listdir('.')
# Out:
# ['child']

# %%
os.chdir(path='child/grandchild')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\afesb\\Desktop\\Real estate project\\new_folder_test\\parent\\child\\grandchild'

# %%
os.rmdir("new_folder_test")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 os.rmdir("new_folder_test")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'new_folder_test'

# %%
os.chdir("c:/Users/afesb/Desktop/Real estate project")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\afesb\\Desktop\\Real estate project'

# %%
os.rmdir('new_folder_test')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 os.rmdir('new_folder_test')
#
# OSError: [WinError 145] The directory is not empty: 'new_folder_test'

# %%
os.path.exists('data.csv')
# Out:
# False

# %%
os.path.isfile('data.csv')
# Out:
# False

# %%
os.path.isdir('new_folder_test')
# Out:
# True

# %%
os.path.isdir('new_folder_test/parent/child/grandchild')
# Out:
# True

# %%
#Join paths safely (avoiding broken paths)
file_path = os.path.join('data', 'file.csv')

# %%
file_path
# Out:
# 'data\\file.csv'

# %%
#Get filename from path
os.path.basename('/home/user/file.txt')
# Out:
# 'file.txt'

# %%
os.path.dirname('c:/Users/afesb/Desktop/Real estate project')
# Out:
# 'c:/Users/afesb/Desktop'
